# %% [markdown]
# # Flow - Advanced
#
# **Goal:** Learn conditionals, loops, and comprehensions.
#
# **Key Takeaways:**
# -
# -
# -

# %% [markdown]
# ## Introduction
#
# [Introduction content will go here]

# %%
# Your code here
