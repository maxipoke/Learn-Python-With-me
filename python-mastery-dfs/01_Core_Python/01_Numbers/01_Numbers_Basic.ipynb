# %% [markdown]
# # Numbers - Basic
#
# **Goal:** Master the fundamental syntax, operations, and standard methods for working with numeric types in Python.
#
# **Key Takeaways:**
# -
# -
# -

# %% [markdown]
# ## Introduction
#
# Python provides several numeric types to represent different kinds of numbers. This notebook covers the basics of working with integers, floats, and complex numbers.

# %%
# Your code here
