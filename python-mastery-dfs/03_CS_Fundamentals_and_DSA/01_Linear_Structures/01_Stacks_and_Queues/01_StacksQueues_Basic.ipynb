# %% [markdown]
# # StacksQueues - Basic
#
# **Goal:** Master list implementation and deque for stacks and queues.
#
# **Key Takeaways:**
# -
# -
# -

# %% [markdown]
# ## Introduction
#
# [Introduction content will go here]

# %%
# Your code here
