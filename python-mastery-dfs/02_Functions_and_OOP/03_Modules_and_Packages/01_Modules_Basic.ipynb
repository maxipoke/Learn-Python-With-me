# %% [markdown]
# # Modules - Basic
#
# **Goal:** Learn the import system, namespace packages, and distribution.
#
# **Key Takeaways:**
# -
# -
# -

# %% [markdown]
# ## Introduction
#
# [Introduction content will go here]

# %%
# Your code here
